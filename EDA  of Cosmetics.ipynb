# %% [markdown]
# ## Cosmetics
# Cosmetics are constituted mixtures of chemical compounds derived from either natural sources, or synthetically created ones. Cosmetics have various purposes. Those designed for personal care and skin care can be used to cleanse or protect the body or skin. Cosmetics designed to enhance or alter one's appearance (makeup) can be used to conceal blemishes, enhance one's natural features (such as the eyebrows and eyelashes), add color to a person's face, or change the appearance of the face entirely to resemble a different person, creature or object. Due to the harsh ingredients in makeup products, individuals with acne-prone skin are more likely to suffer from breakouts. Cosmetics can also be designed to add fragrance to the body.

# %% [markdown]
# ## Source of Data

# %% [markdown]
# <img src='OIP.jpg' width="400" height="400">
#
#
# https://www.kaggle.com/datasets/kingabzpro/cosmetics-datasets

# %% [markdown]
#  ## OBJECTIVES
# * In this demo my objective is to find the relationship between price and rank.
# * In this program my objective is o analyze the given cosmetics data.

# %% [markdown]
# ## Importing Libraries

# %%
#importing numpy pandas mathplot and other methods
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
#first read the data file
df= pd.read_csv('cosmetics.csv')

# %%
#quick look to dataset 
df.head(15)
# Out:
#           Label               Brand  \
# 0   Moisturizer              LA MER
# 1   Moisturizer               SK-II
# 2   Moisturizer      DRUNK ELEPHANT
# 3   Moisturizer              LA MER
# 4   Moisturizer        IT COSMETICS
# 5   Moisturizer              TATCHA
# 6   Moisturizer      DRUNK ELEPHANT
# 7   Moisturizer      DRUNK ELEPHANT
# 8   Moisturizer  KIEHL'S SINCE 1851
# 9   Moisturizer              LA MER
# 10  Moisturizer               FRESH
# 11  Moisturizer  KIEHL'S SINCE 1851
# 12  Moisturizer               BELIF
# 13  Moisturizer        SUNDAY RILEY
# 14  Moisturizer             FARMACY
#
#                                                  Name  Price  Rank  \
# 0                                     Crème de la Mer    175   4.1
# 1                            Facial Treatment Essence    179   4.1
# 2                          Protini™ Polypeptide Cream     68   4.4
# 3                         The Moisturizing Soft Cream    175   3.8
# ...

# %%
#Print summary statistics
df.describe()
# Out:
#              Price         Rank  Combination          Dry       Normal  \
# count  1472.000000  1472.000000   1472.00000  1472.000000  1472.000000
# mean     55.584239     4.153261      0.65625     0.614130     0.652174
# std      45.014429     0.633918      0.47512     0.486965     0.476442
# min       3.000000     0.000000      0.00000     0.000000     0.000000
# 25%      30.000000     4.000000      0.00000     0.000000     0.000000
# 50%      42.500000     4.300000      1.00000     1.000000     1.000000
# 75%      68.000000     4.500000      1.00000     1.000000     1.000000
# max     370.000000     5.000000      1.00000     1.000000     1.000000
#
#               Oily    Sensitive
# count  1472.000000  1472.000000
# mean      0.607337     0.513587
# std       0.488509     0.499985
# min       0.000000     0.000000
# 25%       0.000000     0.000000
# 50%       1.000000     1.000000
# 75%       1.000000     1.000000
# max       1.000000     1.000000

# %% [markdown]
# * From the given data total 1472 products data.
# * The minimum rank and minimum price is 0 and 3 respectively.
# * The mean of price is 55.5 and rank is 4.1
# * the standard deviation of price is 45 and rank is 0.63.
# * The 25% product priced 30 and ranked 4
# * The 50% product priced 42.5 and ranked 4.3
# * The 75% product priced 68 and ranked 4.5
# * The maximum product priced 370 and ranked 5.

# %%
df.info()
#datatype------dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1472 entries, 0 to 1471
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Label        1472 non-null   object
#  1   Brand        1472 non-null   object
#  2   Name         1472 non-null   object
#  3   Price        1472 non-null   int64
#  4   Rank         1472 non-null   float64
#  5   Ingredients  1472 non-null   object
#  6   Combination  1472 non-null   int64
#  7   Dry          1472 non-null   int64
#  8   Normal       1472 non-null   int64
#  9   Oily         1472 non-null   int64
#  10  Sensitive    1472 non-null   int64
# dtypes: float64(1), int64(6), object(4)
# memory usage: 126.6+ KB

# %% [markdown]
# * datatype is dataframe.
# * here the dtype describes the datatype.
# * object=string,,,,,int64=number and in 64 is bits
# * Memory usuage gives us the idea about the space it takes
# * To change the string into number it helps to know
# * for eg the above shows object =4 i.e I know the no of string and same goes with integer
# * the non-null means no missing cell

# %%
# Inspect missing values in the dataset
print(df.isnull().values.sum())
# Out:
# 0

# %% [markdown]
# We see that this data do not contain any missing value

# %% [markdown]
# We are good to go for EDA Cycle

# %%
#Seaborn Histogram
sns.displot(data=df,x="Price")
#Add labels
plt.title('Price count')
plt.xlabel('Price')


plt.ylabel('Count')
# Out:
# Text(4.944444444444445, 0.5, 'Count')

# %% [markdown]
# * The above figure is histogram for price counting.
# * It shows that the products of price 50 is the most in 200.
# * The minimum price of 350 and above is either 1 or 2.

# %%
sns.barplot(data=df,x="Rank",y="Price",width=0.5)
# Out:
# <Axes: xlabel='Rank', ylabel='Price'>

# %% [markdown]
#     * The above shows the barplot between rank and prices.

# %%
sns.displot(data=df,x="Price",kind="kde")

# %% [markdown]
# * The above is the displot of price.
# * It is right skewed.

# %%
sns.displot(data=df,x="Rank",kind="kde")

# %% [markdown]
# * It is thd displot for rank of the products.
# * It is left skewed.

# %%
# Create a scatterplot 
sns.scatterplot(x = df['Rank'],y=df['Price'], hue=df['Oily'])

#Optionally ,add labels and a tittle
plt.title('Scatterplot of Rank vs Price')
plt.xlabel('Rank')
plt.ylabel('Price')

#Show the plot
plt.show()

# %% [markdown]
# * The given scatterplot is for the price and range for oily skin products.
# * The 0 is oily skin products and 1 is others.
# * The oily skin product has best ranking for prices 25-200.
# * The other products at ranking above 3 are mosly cheap.
# * The oily skin product have 3-5 ranking for prices 0 to 100.

# %%
# line plot 
sns.lineplot(x='Price',y='Rank', data=df )
# Out:
# <Axes: xlabel='Price', ylabel='Rank'>

# %% [markdown]
# * The given lineplot is between rank and price of products.
# * This shows that the best products are in range from 175 to 225 according to rank 1.
# * The wrost product ranges from 300-350 with a least rank 5.

# %%
#box plot
sns.boxplot(y = 'Price',data= df, x= 'Oily')
plt.xlabel('Oily')
# Out:
# Text(0.5, 0, 'Oily')

# %% [markdown]
# # For Yes(0)
# * it is left skewed
# * the max = 125 and min= 0
# * the median is 48
# * There are outliners from 125 t 350 and above.
# # For no(1)
# * it is left skewed
# * the max=128 and min= 5
# * the median is 50
# * There are outliners from 125 t 350 and above.

# %%
#this is heat map pearson correlation matrix
corrmat = df.corr()
f, ax = plt.subplots(figsize=(16, 12))
sns.heatmap(corrmat, vmax=.8, square=True);
# Out:
# C:\Users\ANU'S LAPTOP\AppData\Local\Temp\ipykernel_9728\1752742378.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corrmat = df.corr()

# %%
plt.figure(figsize=(20,20))
plt.title('Pearsn Correlation of Features',size=15)
colormap= sns.diverging_palette(10,220,as_cmap = True)
sns.heatmap(df.corr(),square= True, annot=True,linewidths=0.1,vmax=1.0,linecolor='white',annot_kws={'fontsize':12})
plt.show()
# Out:
# C:\Users\ANU'S LAPTOP\AppData\Local\Temp\ipykernel_9728\2370769945.py:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),square= True, annot=True,linewidths=0.1,vmax=1.0,linecolor='white',annot_kws={'fontsize':12})

# %% [markdown]
# In above correlation matrix, we printed the number also so it will be easy for us to see which are highly corelated Value close to 1.00 is highly corelated
#
# As per our objective,we see that "price" and "rank" have value -0.025 which is below 0.0 and we can say that they are not correlated.

# %% [markdown]
# Since our objective is done hence our EDA finishes.
